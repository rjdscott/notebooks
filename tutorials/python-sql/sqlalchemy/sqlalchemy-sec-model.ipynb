# %%
import numpy as np
import pandas as pd
import os
from sqlalchemy import create_engine
import mysql.connector

# %%
engine = create_engine("mysql+mysqlconnector://rob:rob123@35.189.0.145/omnidb")

# %%
connection = engine.connect()
result = connection.execute("SELECT distinct(sec_code) FROM omnidb.eod_holdings_omkt;")
for row in result:
    print("sec code:", row['sec_code'])
connection.close()
# Out:
# ('sec code:', u'IXI')
# ('sec code:', u'ILB')
# ('sec code:', u'DJRE')
# ('sec code:', u'NDQ')
# ('sec code:', u'VAP')
# ('sec code:', u'VAF')
# ('sec code:', u'8EC')
# ('sec code:', u'WFD')
# ('sec code:', u'VHY')
# ('sec code:', u'ETF')
# ('sec code:', u'AAA')
# ('sec code:', u'HVST')
# ('sec code:', u'ZYAU')
# ('sec code:', u'DMKT')
# ('sec code:', u'VGS')
# ('sec code:', u'VSO')
# ('sec code:', u'MOAT')
# ('sec code:', u'IAA')
# ('sec code:', u'IOZ')
# ('sec code:', u'RCB')
# ('sec code:', u'VGAD')
# ('sec code:', u'VGE')
# ('sec code:', u'S32')
# ('sec code:', u'VAS')
# ('sec code:', u'MAI')
# ('sec code:', u'CDD')
# ('sec code:', u'WPL')
# ('sec code:', u'RIO')
# ('sec code:', u'ANZ')
# ('sec code:', u'ZYUS')
# ('sec code:', u'NAB')
# ('sec code:', u'CBA')
# ('sec code:', u'WBC')
# ('sec code:', u'ISO')
# ('sec code:', u'CYB')
# ('sec code:', u'IVC')
# ('sec code:', u'QBE')
# ('sec code:', u'ORL')
# ('sec code:', u'WES')
# ('sec code:', u'WXHG')
# ('sec code:', u'GXL')
# ...
